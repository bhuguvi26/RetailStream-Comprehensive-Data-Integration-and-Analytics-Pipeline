# %% [markdown]
# <a href="https://colab.research.google.com/github/bhuguvi26/RetailStream-Comprehensive-Data-Integration-and-Analytics-Pipeline/blob/main/RetailStream_Comprehensive_Data_Integration_and_Analytics_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Single-cell Colab pipeline: GitHub -> S3 -> Spark -> Analysis -> S3
# Run in Google Colab (Python 3). Installs required packages automatically.
# IMPORTANT: Enter AWS credentials when prompted.

# -------------------------
# Install dependencies
# -------------------------
# (may take a minute)
# !pip install -q boto3 gitpython findspark pyspark==3.3.2

import os, sys, time, shutil, tempfile, json, subprocess
from getpass import getpass

# -------------------------
# User inputs (confirm)
# -------------------------
print("\n--- Config: provide details when prompted ---\n")
GIT_REPO = "https://github.com/bhuguvi26/RetailStream-Comprehensive-Data-Integration-and-Analytics-Pipeline.git"
# Default repo folders to scan for CSVs (adjust if your layout differs)
REPO_CSV_FOLDERS = ["Features_data_set", "Sales_Dataset", "Store_Dataset", "Stores_data_set", "Sales_Dataset"]
DEFAULT_RAW_BUCKET = "retailstream-raw"
DEFAULT_PROCESSED_BUCKET = "retailstream-processed"

aws_key = "AKIAXJ6ZHROTHSV54HF7"
aws_secret ="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"
aws_region = input("AWS Region (default: ap-southeast-2): ").strip() or "ap-southeast-2"

raw_bucket = input("S3 RAW bucket name (default: {}): ".format(DEFAULT_RAW_BUCKET)).strip() or DEFAULT_RAW_BUCKET
processed_bucket = input("S3 PROCESSED bucket name (default: {}): ".format(DEFAULT_PROCESSED_BUCKET)).strip() or DEFAULT_PROCESSED_BUCKET

if not aws_key:
    # allow environment variables to be used (if set)
    if not (os.environ.get("AWS_ACCESS_KEY_ID") and os.environ.get("AWS_SECRET_ACCESS_KEY")):
        print("No AWS credentials provided and none found in environment. Exiting.")
        raise SystemExit(1)
else:
    # set environment variables for boto3
    os.environ["AWS_ACCESS_KEY_ID"] = aws_key
    os.environ["AWS_SECRET_ACCESS_KEY"] = aws_secret
    os.environ["AWS_DEFAULT_REGION"] = aws_region

# -------------------------
# Imports (after pip)
# -------------------------
import boto3
from botocore.exceptions import ClientError
import git
import findspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, month, year, sum as _sum, avg as _avg, desc

# -------------------------
# Helper utilities
# -------------------------
session = boto3.Session(
    aws_access_key_id=os.environ.get("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.environ.get("AWS_SECRET_ACCESS_KEY"),
    region_name=aws_region
)
s3_client = session.client("s3")
s3_resource = session.resource("s3")

def bucket_exists(name):
    try:
        s3_client.head_bucket(Bucket=name)
        return True
    except ClientError as e:
        return False

def create_bucket_if_missing(name, region):
    if bucket_exists(name):
        print("Bucket exists:", name)
        return
    print("Creating bucket:", name)
    try:
        if region == "us-east-1":
            s3_client.create_bucket(Bucket=name)
        else:
            s3_client.create_bucket(Bucket=name, CreateBucketConfiguration={'LocationConstraint': region})
        print("Created bucket:", name)
    except ClientError as e:
        print("Failed to create bucket:", e)
        raise

def upload_file(local_path, bucket, key):
    s3_client.upload_file(local_path, bucket, key)
    print("Uploaded to s3://{}/{}".format(bucket, key))

def download_file(bucket, key, local_path):
    s3_client.download_file(bucket, key, local_path)
    # print("Downloaded s3://{}/{} -> {}".format(bucket, key, local_path))

# -------------------------
# Step 1: Clone repo locally
# -------------------------
WORKDIR = "/content/retail_repo"
if os.path.exists(WORKDIR):
    print("Repo already present at", WORKDIR, " — pulling latest changes if possible.")
    try:
        r = git.Repo(WORKDIR)
        r.remote().pull()
    except Exception as e:
        print("git pull failed (continuing with existing copy):", e)
else:
    print("Cloning repo:", GIT_REPO)
    try:
        git.Repo.clone_from(GIT_REPO, WORKDIR, depth=1)
        print("Cloned to", WORKDIR)
    except Exception as e:
        print("git clone failed:", e)
        print("If cloning fails due to TLS/network, upload files manually to Colab then re-run.")
        raise SystemExit(1)

# -------------------------
# Step 2: Find CSV files in repo folders
# -------------------------
print("\nScanning repository for CSV files under:", REPO_CSV_FOLDERS)
files_to_upload = []
for folder in REPO_CSV_FOLDERS:
    path = os.path.join(WORKDIR, folder)
    if not os.path.exists(path):
        # try lowercase or slight variants
        path_alt = os.path.join(WORKDIR, folder.lower())
        if os.path.exists(path_alt):
            path = path_alt
        else:
            # skip missing paths
            print("  (warning) path not found:", folder)
            continue
    for root, dirs, files in os.walk(path):
        for f in files:
            if f.lower().endswith(".csv"):
                local = os.path.join(root, f)
                # build s3 key: foldername/filename
                prefix = os.path.basename(folder).lower().replace(" ", "_")
                key = "{}/{}".format(prefix, f)
                files_to_upload.append((local, key))

if not files_to_upload:
    print("No CSV files found in repo paths. Exiting.")
    raise SystemExit(1)

print("Found {} CSV files to upload.".format(len(files_to_upload)))
for local, key in files_to_upload[:50]:
    print(" -", local, "->", key)

# -------------------------
# Step 3: Ensure S3 buckets exist (create them if needed)
# -------------------------
print("\nEnsuring S3 buckets exist (RAW and PROCESSED)")
create_bucket_if_missing(raw_bucket, aws_region)
create_bucket_if_missing(processed_bucket, aws_region)

# -------------------------
# Step 4: Upload CSVs to RAW bucket
# -------------------------
print("\nUploading CSVs to s3://{}/".format(raw_bucket))
uploaded_keys = []
for local, key in files_to_upload:
    try:
        upload_file(local, raw_bucket, key)
        uploaded_keys.append(key)
    except Exception as e:
        print("Upload failed for", local, ":", e)

print("Uploaded {} objects to s3://{}".format(len(uploaded_keys), raw_bucket))

# -------------------------
# Step 5: Download uploaded files locally into /content/data_for_spark
# (This ensures Spark can read them reliably in Colab)
# -------------------------
LOCAL_DATA_DIR = "/content/data_for_spark"
if os.path.exists(LOCAL_DATA_DIR):
    shutil.rmtree(LOCAL_DATA_DIR)
os.makedirs(LOCAL_DATA_DIR)

print("\nDownloading uploaded objects from S3 to local folder for Spark ingestion...")
for key in uploaded_keys:
    # strip prefix path pieces for local filename safety
    fname = key.replace("/", "__")
    local_path = os.path.join(LOCAL_DATA_DIR, fname)
    try:
        download_file(raw_bucket, key, local_path)
    except Exception as e:
        print("Failed to download s3://{}/{} -> {}".format(raw_bucket, key, local_path, e))

print("Local data directory for Spark:", LOCAL_DATA_DIR)
print("Files:", len(os.listdir(LOCAL_DATA_DIR)))

# -------------------------
# Step 6: Start Spark (local) and read CSVs
# -------------------------
print("\nStarting local SparkSession (this may take ~20 seconds)...")
# Configure findspark / environment (Colab)
findspark.init()

# Create Spark session
spark = SparkSession.builder \
    .appName("RetailStreamColab") \
    .config("spark.driver.memory", "4g") \
    .config("spark.sql.session.timeZone", "UTC") \
    .getOrCreate()

print("Spark version:", spark.version)

# Read all CSV files in local data folder into a dict of DataFrames
from pyspark.sql import DataFrame
dfs = {}
for fname in sorted(os.listdir(LOCAL_DATA_DIR)):
    if not fname.lower().endswith(".csv"):
        continue
    local_path = os.path.join(LOCAL_DATA_DIR, fname)
    try:
        df = spark.read.option("header", "true").option("inferSchema", "true").csv(local_path)
        keyname = fname.replace("__", "/")
        dfs[keyname] = df
        print("Loaded:", keyname, "rows:", df.count(), "columns:", len(df.columns))
    except Exception as e:
        print("Failed to load", local_path, ":", e)

if not dfs:
    print("No DataFrames loaded. Exiting.")
    raise SystemExit(1)

# -------------------------
# Step 7: Inspect DataFrames and map likely datasets
# -------------------------
print("\nAvailable DataFrames and sample columns:")
for k, df in dfs.items():
    print("==", k, "==")
    print("  columns:", df.columns)
    # show small sample
    try:
        df.show(3)
    except:
        pass

# Try to identify sales / stores / features by filename hints
sales_df = None
stores_df = None
features_df = None
for key, df in dfs.items():
    kl = key.lower()
    if "sales" in kl or "sale" in kl or "sales_sample" in kl:
        sales_df = df
    if "store" in kl or "stores" in kl:
        stores_df = df
    if "feature" in kl or "features" in kl:
        features_df = df

# fallback: if not detected explicitly, pick the largest one as sales
if sales_df is None and dfs:
    # choose DF with highest row count
    sales_df = max(dfs.values(), key=lambda d: d.count())

print("\nIdentified DataFrames:")
print(" sales_df:", "Yes" if sales_df is not None else "No")
print(" stores_df:", "Yes" if stores_df is not None else "No")
print(" features_df:", "Yes" if features_df is not None else "No")

# -------------------------
# Step 8: Basic cleaning helpers
# -------------------------
from pyspark.sql.functions import to_date, regexp_replace

def safe_column(df, candidates):
    """Return first matching column name from candidates present in df.columns"""
    cols = [c for c in df.columns]
    for cand in candidates:
        for c in cols:
            if c.lower() == cand.lower():
                return c
    # try substring matching
    for cand in candidates:
        for c in cols:
            if cand.lower() in c.lower():
                return c
    return None

# Normalize stores_df: ensure it has 'store' or 'store_id' and a 'city' column if possible
if stores_df is not None:
    # print sample
    pass

# Ensure date parsing for sales_df if it has a date-like column
date_col = None
if sales_df is not None:
    date_col = safe_column(sales_df, ["date", "sale_date", "transaction_date"])
    if date_col:
        try:
            sales_df = sales_df.withColumn("__date", to_date(col(date_col)))
            sales_df = sales_df.drop(date_col).withColumnRenamed("__date", date_col)
            print("Parsed date column:", date_col)
        except Exception as e:
            print("Date parse failed:", e)

# Standardize numeric sales/price column names
price_col = safe_column(sales_df, ["price", "amount", "sales", "sale_amount", "total"])
if price_col:
    try:
        sales_df = sales_df.withColumn(price_col, regexp_replace(col(price_col).cast("string"), "[^0-9.\\-]", "").cast("double"))
        print("Normalized price column:", price_col)
    except Exception as e:
        print("Price normalization failed:", e)

# Standardize store column
store_col = safe_column(sales_df, ["store", "store_id", "city", "location"])
if store_col:
    print("Using store column:", store_col)
else:
    print("No obvious store column in sales data. Some aggregations may be skipped.")

# -------------------------
# Step 9: Business-case calculations (best-effort)
# -------------------------
print("\n--- Business Calculations (best-effort) ---\n")

results = {}

# 1) Monthly aggregation: total sales by month (if date and price exist)
if date_col and price_col:
    try:
        monthly = sales_df.withColumn("month", month(col(date_col))).groupBy("month").agg(_sum(col(price_col)).alias("total_sales")).orderBy("month")
        print("Monthly aggregation (month, total_sales):")
        monthly.show(12)
        results["monthly_sales"] = monthly
    except Exception as e:
        print("Monthly aggregation failed:", e)
else:
    print("Skipping monthly aggregation (missing date or price).")

# 2) Weekly top-performing store (approx using id->week or date->week if date present)
from pyspark.sql.functions import weekofyear
if date_col and price_col and store_col:
    try:
        weekly = sales_df.withColumn("week", weekofyear(col(date_col))) \
                         .groupBy("week", col(store_col)) \
                         .agg(_sum(col(price_col)).alias("week_sales"))
        from pyspark.sql.window import Window
        from pyspark.sql.functions import row_number
        w = Window.partitionBy("week").orderBy(desc("week_sales"))
        weekly_top = weekly.withColumn("rn", row_number().over(w)).filter(col("rn") == 1).drop("rn")
        print("Weekly top-performing store (week, store, week_sales):")
        weekly_top.show(10)
        results["weekly_top_store"] = weekly_top
    except Exception as e:
        print("Weekly top-performing store failed:", e)
else:
    print("Skipping weekly top store (missing date/price/store).")

# 3) Leap year worst store: find min total sales for leap years if date exists
if date_col and price_col and store_col:
    try:
        leap = sales_df.withColumn("yr", year(col(date_col))).filter((col("yr") % 4) == 0) \
                       .groupBy(col(store_col)).agg(_sum(col(price_col)).alias("leap_sales")) \
                       .orderBy("leap_sales")
        print("Stores ordered by leap-year sales (lowest first):")
        leap.show(10)
        results["leap_worst"] = leap
    except Exception as e:
        print("Leap-year analysis failed:", e)
else:
    print("Skipping leap-year analysis (missing date/price/store).")

# 4) Department performance (by category/product) if available
cat_col = safe_column(sales_df, ["category", "department", "product_category"])
if cat_col and price_col:
    try:
        dept = sales_df.groupBy(cat_col).agg(_sum(col(price_col)).alias("total_sales")).orderBy(desc("total_sales"))
        print("Department performance by total sales:")
        dept.show(10)
        results["dept_performance"] = dept
    except Exception as e:
        print("Department performance failed:", e)
else:
    print("Skipping department performance (no category or price found).")

# 5) Example: average customer visits in type B stores during April
# This requires columns like 'visits', 'store_type', and date. We'll attempt best-effort:
visits_col = safe_column(sales_df, ["visits", "customer_visits", "footfall"])
store_type_col = safe_column(sales_df, ["store_type", "type"])
if date_col and visits_col and store_type_col:
    try:
        april_avg = sales_df.withColumn("month", month(col(date_col))) \
            .filter((col("month") == 4) & (col(store_type_col).rlike("(?i)B"))) \
            .groupBy(col(store_type_col)) \
            .agg(_avg(col(visits_col)).alias("avg_visits"))
        print("Average visits for type B stores during April:")
        april_avg.show()
        results["april_visits_typeB"] = april_avg
    except Exception as e:
        print("April visits calc failed:", e)
else:
    print("Skipping April visits (missing visits, store_type or date).")

# 6) Fuel price analysis (requires 'fuel' related column)
fuel_col = safe_column(sales_df, ["fuel_price", "fuel", "petrol_price"])
if fuel_col and store_col:
    try:
        fuel_weekly = sales_df.withColumn("week", weekofyear(col(date_col)) if date_col else None).groupBy("week", col(store_col)).agg(_avg(col(fuel_col)).alias("avg_fuel"))
        print("Fuel price weekly (sample):")
        if fuel_weekly is not None:
            fuel_weekly.show(5)
            results["fuel_weekly"] = fuel_weekly
    except Exception as e:
        print("Fuel price calc failed:", e)
else:
    print("Skipping fuel price analysis (no fuel or store column).")

# 7) Save results to local CSV files and upload to processed S3 bucket
OUT_DIR = "/content/processed_outputs"
if os.path.exists(OUT_DIR):
    shutil.rmtree(OUT_DIR)
os.makedirs(OUT_DIR)

def save_df_to_csv(spark_df, filename):
    local_tmp = os.path.join(OUT_DIR, filename)
    # coalesce to 1 partition for neat CSV
    try:
        spark_df.coalesce(1).write.mode("overwrite").option("header","true").csv(local_tmp)
        # find the part-*.csv in folder and zip it to final CSV for upload
        part = None
        for f in os.listdir(local_tmp):
            if f.startswith("part-") and f.endswith(".csv"):
                part = os.path.join(local_tmp, f)
                break
        if part is None:
            print("No CSV part found for", filename)
            return None
        final = os.path.join(OUT_DIR, filename + ".csv")
        shutil.move(part, final)
        shutil.rmtree(local_tmp)
        return final
    except Exception as e:
        print("Failed to save", filename, ":", e)
        return None

print("\nWriting analysis outputs and uploading to s3://{}/".format(processed_bucket))
create_bucket_if_missing(processed_bucket, aws_region)

uploaded_outputs = []
for name, sdf in results.items():
    try:
        local_csv = save_df_to_csv(sdf, name)
        if local_csv and os.path.exists(local_csv):
            s3_key = "analysis_outputs/{}".format(os.path.basename(local_csv))
            upload_file(local_csv, processed_bucket, s3_key)
            uploaded_outputs.append(s3_key)
    except Exception as e:
        print("Failed to write/upload result", name, ":", e)

print("Uploaded outputs:", uploaded_outputs)

# Final status
print("\n--- Pipeline finished ---")
print("RAW bucket:", raw_bucket)
print("PROCESSED bucket:", processed_bucket)
print("Uploaded {} data files and {} output objects.".format(len(uploaded_keys), len(uploaded_outputs)))
print("Local data dir for Spark:", LOCAL_DATA_DIR)
print("Processed outputs dir:", OUT_DIR)
print("\nYou can now inspect results in S3 or download processed CSVs from s3://{}/analysis_outputs/".format(processed_bucket))

# If you want a downloadable zip of outputs in Colab:
shutil.make_archive("/content/processed_outputs_zip", "zip", OUT_DIR)
print("\nDownload the results ZIP: /content/processed_outputs_zip.zip")
# Out:
# Streaming output truncated to the last 5000 lines.
# Loaded: sales_dataset/Sales_data_set_305.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_306.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_307.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_308.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_309.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_31.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_310.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_311.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_312.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_313.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_314.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_315.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_316.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_317.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_318.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_319.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_32.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_320.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_321.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_322.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_323.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_324.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_325.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_326.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_327.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_328.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_329.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_33.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_330.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_331.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_332.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_333.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_334.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_335.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_336.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_337.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_338.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_339.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_34.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_340.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_341.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_342.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_343.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_344.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_345.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_346.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_347.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_348.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_349.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_35.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_350.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_351.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_352.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_353.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_354.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_355.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_356.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_357.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_358.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_359.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_36.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_360.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_361.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_362.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_363.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_364.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_365.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_366.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_367.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_368.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_369.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_37.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_370.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_371.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_372.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_373.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_374.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_375.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_376.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_377.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_378.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_379.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_38.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_380.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_381.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_382.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_383.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_384.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_385.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_386.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_387.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_388.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_389.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_39.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_390.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_391.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_392.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_393.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_394.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_395.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_396.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_397.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_398.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_399.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_4.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_40.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_400.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_401.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_402.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_403.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_404.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_405.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_406.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_407.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_408.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_409.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_41.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_410.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_411.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_412.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_413.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_414.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_415.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_416.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_417.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_418.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_419.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_42.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_420.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_421.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_422.csv rows: 570 columns: 5
# Loaded: sales_dataset/Sales_data_set_43.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_44.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_45.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_46.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_47.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_48.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_49.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_5.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_50.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_51.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_52.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_53.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_54.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_55.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_56.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_57.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_58.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_59.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_6.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_60.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_61.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_62.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_63.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_64.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_65.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_66.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_67.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_68.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_69.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_7.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_70.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_71.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_72.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_73.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_74.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_75.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_76.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_77.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_78.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_79.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_8.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_80.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_81.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_82.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_83.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_84.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_85.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_86.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_87.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_88.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_89.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_9.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_90.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_91.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_92.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_93.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_94.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_95.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_96.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_97.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_98.csv rows: 1000 columns: 5
# Loaded: sales_dataset/Sales_data_set_99.csv rows: 1000 columns: 5
# Loaded: store_dataset/stores_data_set (1).csv rows: 45 columns: 3
#
# Available DataFrames and sample columns:
# == features_data_set/Features_data_set_1.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5|        CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |    1|05/02/2010|      42.31|     2.572|     null|     null|     null|     null|     null|211.0963582|       8.106|    false|
# |    1|12/02/2010|      38.51|     2.548|     null|     null|     null|     null|     null|211.2421698|       8.106|     true|
# |    1|19/02/2010|      39.93|     2.514|     null|     null|     null|     null|     null|211.2891429|       8.106|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# only showing top 3 rows
#
# == features_data_set/Features_data_set_2.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5|        CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |    6|28/10/2011|      69.51|     3.372|     null|     null|     null|     null|     null| 219.237049|       6.551|    false|
# |    6|04/11/2011|      58.54|     3.332|     null|     null|     null|     null|     null|219.4000812|       6.551|    false|
# |    6|11/11/2011|      61.33|     3.297| 12590.41|  2173.66|    123.2|  3108.55|  5416.96|219.5631135|       6.551|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# only showing top 3 rows
#
# == features_data_set/Features_data_set_3.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5|        CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |   11|19/07/2013|      82.06|     3.556|  1554.05|  1169.85|    68.06|   373.45|  1046.13|       null|        null|    false|
# |   11|26/07/2013|      85.64|      3.62|  2387.21|    717.2|    106.7|  1084.84|  3264.52|       null|        null|    false|
# |   12|05/02/2010|      49.47|     2.962|     null|     null|     null|     null|     null|126.4420645|      13.975|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# only showing top 3 rows
#
# == features_data_set/Features_data_set_4.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5|        CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |   17|14/10/2011|      47.69|     3.567|     null|     null|     null|     null|     null|129.7706452|       6.617|    false|
# |   17|21/10/2011|      47.27|     3.579|     null|     null|     null|     null|     null|129.7821613|       6.617|    false|
# |   17|28/10/2011|      41.89|     3.567|     null|     null|     null|     null|     null|129.7936774|       6.617|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# only showing top 3 rows
#
# == features_data_set/Features_data_set_5.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5| CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# |   22|05/07/2013|      75.13|     3.643| 10445.17|  2347.05|    376.2|  6679.54|   859.63|null|        null|    false|
# |   22|12/07/2013|      77.78|     3.645|  3289.92|  1101.45|     27.7|   1801.7|  1244.52|null|        null|    false|
# |   22|19/07/2013|      80.67|     3.803|  1117.95|  1068.78|   192.45|    374.0|   835.61|null|        null|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# only showing top 3 rows
#
# == features_data_set/Features_data_set_6.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5|        CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |   28|30/09/2011|      83.26|     3.877|     null|     null|     null|     null|     null|129.6060667|      13.503|    false|
# |   28|07/10/2011|      70.44|     3.827|     null|     null|     null|     null|     null|   129.6938|       12.89|    false|
# |   28|14/10/2011|      67.31|     3.805|     null|     null|     null|     null|     null|129.7706452|       12.89|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# only showing top 3 rows
#
# == features_data_set/Features_data_set_7.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5| CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# |   33|21/06/2013|      93.62|     3.766|   240.37|     null|     null|     null|   440.96|null|        null|    false|
# |   33|28/06/2013|      92.98|     3.781|   873.21|     null|     null|     null|   559.31|null|        null|    false|
# |   33|05/07/2013|      99.66|     3.753|   146.05|     null|     null|      3.9|  1423.19|null|        null|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# only showing top 3 rows
#
# == features_data_set/Features_data_set_8.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5|        CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# |   39|16/09/2011|      83.11|     3.526|     null|     null|     null|     null|     null|214.7934111|       8.177|    false|
# |   39|23/09/2011|      78.75|     3.467|     null|     null|     null|     null|     null|215.1233185|       8.177|    false|
# |   39|30/09/2011|      81.51|     3.355|     null|     null|     null|     null|     null|215.4532259|       8.177|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+-----------+------------+---------+
# only showing top 3 rows
#
# == features_data_set/Features_data_set_9.csv ==
#   columns: ['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'IsHoliday']
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# |Store|      Date|Temperature|Fuel_Price|MarkDown1|MarkDown2|MarkDown3|MarkDown4|MarkDown5| CPI|Unemployment|IsHoliday|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# |   44|07/06/2013|      67.49|     3.779|  1169.72|     null|     4.86|     76.2|   516.85|null|        null|    false|
# |   44|14/06/2013|      76.41|     3.771|   351.38|     null|     4.89|     6.35|   867.28|null|        null|    false|
# |   44|21/06/2013|      70.49|      3.74|    94.88|     null|     1.82|     null|   806.75|null|        null|    false|
# +-----+----------+-----------+----------+---------+---------+---------+---------+---------+----+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_1.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    1|   1|05/02/2010|     24924.5|    false|
# |    1|   1|12/02/2010|    46039.49|     true|
# |    1|   1|19/02/2010|    41595.55|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_10.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    1|  90|25/03/2011|     74628.5|    false|
# |    1|  90|01/04/2011|     74995.0|    false|
# |    1|  90|08/04/2011|    83707.82|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_100.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|   9|04/06/2010|    26977.49|    false|
# |   11|   9|11/06/2010|    22995.61|    false|
# |   11|   9|18/06/2010|     19460.6|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_101.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|  17|28/05/2010|     11591.0|    false|
# |   11|  17|04/06/2010|    12607.89|    false|
# |   11|  17|11/06/2010|    11595.67|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_102.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|  24|18/11/2011|     7947.87|    false|
# |   11|  24|25/11/2011|    13049.73|     true|
# |   11|  24|02/12/2011|    10360.67|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_103.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|  31|11/11/2011|     3464.22|    false|
# |   11|  31|18/11/2011|     2725.46|    false|
# |   11|  31|25/11/2011|     2671.45|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_104.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|  38|04/11/2011|     75978.3|    false|
# |   11|  38|11/11/2011|    63856.32|    false|
# |   11|  38|18/11/2011|    63284.77|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_105.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|  49|24/08/2012|      8307.3|    false|
# |   11|  49|31/08/2012|     8202.33|    false|
# |   11|  49|07/09/2012|     9090.21|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_106.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|  67|11/06/2010|     9541.96|    false|
# |   11|  67|18/06/2010|    12961.25|    false|
# |   11|  67|25/06/2010|    12529.43|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_107.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|  82|19/03/2010|    18161.97|    false|
# |   11|  82|26/03/2010|    16202.17|    false|
# |   11|  82|02/04/2010|    19227.99|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_108.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|  93|12/03/2010|    27581.85|    false|
# |   11|  93|19/03/2010|    28996.36|    false|
# |   11|  93|26/03/2010|    26711.14|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_109.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|   1|30/12/2011|    22801.73|     true|
# |   12|   1|06/01/2012|    14916.13|    false|
# |   12|   1|13/01/2012|    13906.43|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_11.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    1|  97|12/08/2011|    37747.44|    false|
# |    1|  97|19/08/2011|    38711.47|    false|
# |    1|  97|26/08/2011|    33691.44|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_110.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|   8|23/12/2011|    46727.91|    false|
# |   12|   8|30/12/2011|    38915.45|     true|
# |   12|   8|06/01/2012|    42042.83|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_111.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|  16|16/12/2011|      2151.6|    false|
# |   12|  16|23/12/2011|     2081.81|    false|
# |   12|  16|30/12/2011|      1459.9|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_112.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|  23|29/06/2012|    37419.29|    false|
# |   12|  23|06/07/2012|    38876.93|    false|
# |   12|  23|13/07/2012|    38852.23|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_113.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|  30|22/06/2012|     5464.96|    false|
# |   12|  30|29/06/2012|     5794.04|    false|
# |   12|  30|06/07/2012|     5312.97|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_114.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|  38|15/06/2012|    64029.26|    false|
# |   12|  38|22/06/2012|    53440.08|    false|
# |   12|  38|29/06/2012|    52691.22|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_115.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|  52|25/11/2011|     7479.45|     true|
# |   12|  52|02/12/2011|     4752.99|    false|
# |   12|  52|09/12/2011|     4469.49|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_116.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|  67|17/02/2012|    17117.37|    false|
# |   12|  67|24/02/2012|     5665.43|    false|
# |   12|  67|02/03/2012|     5446.81|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_117.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|  82|28/10/2011|    14879.14|    false|
# |   12|  82|04/11/2011|     14655.9|    false|
# |   12|  82|11/11/2011|    15854.49|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_118.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   12|  93|21/10/2011|      551.78|    false|
# |   12|  93|28/10/2011|       481.3|    false|
# |   12|  93|04/11/2011|       840.0|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_119.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|   3|02/03/2012|    20025.59|    false|
# |   13|   3|09/03/2012|    19922.86|    false|
# |   13|   3|16/03/2012|    18142.44|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_12.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    2|   6|19/11/2010|     7668.48|    false|
# |    2|   6|26/11/2010|     27228.0|     true|
# |    2|   6|03/12/2010|     7397.88|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_120.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  10|24/02/2012|    26696.15|    false|
# |   13|  10|02/03/2012|    29278.51|    false|
# |   13|  10|09/03/2012|    27320.17|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_121.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  18|06/07/2012|        0.97|    false|
# |   13|  18|13/07/2012|         0.1|    false|
# |   13|  18|03/08/2012|         0.1|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_122.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  25|10/08/2012|    13160.18|    false|
# |   13|  25|17/08/2012|    16025.83|    false|
# |   13|  25|24/08/2012|    16181.66|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_123.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  32|03/08/2012|    11379.63|    false|
# |   13|  32|10/08/2012|    10710.47|    false|
# |   13|  32|17/08/2012|     10755.8|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_124.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  40|27/07/2012|    73127.59|    false|
# |   13|  40|03/08/2012|    78588.62|    false|
# |   13|  40|10/08/2012|    78201.98|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_125.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  50|03/09/2010|      2512.0|    false|
# |   13|  50|10/09/2010|      1829.0|     true|
# |   13|  50|17/09/2010|      1931.0|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_126.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  59|11/05/2012|      488.83|    false|
# |   13|  59|18/05/2012|      467.19|    false|
# |   13|  59|25/05/2012|      429.21|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_127.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  80|02/03/2012|    18680.44|    false|
# |   13|  80|09/03/2012|    18596.76|    false|
# |   13|  80|16/03/2012|    19439.35|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_128.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  91|24/02/2012|    81112.84|    false|
# |   13|  91|02/03/2012|    82325.66|    false|
# |   13|  91|09/03/2012|    86011.34|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_129.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   13|  98|17/02/2012|    18366.65|    false|
# |   13|  98|24/02/2012|    13421.29|    false|
# |   13|  98|02/03/2012|    14103.52|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_13.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    2|  13|12/11/2010|    47466.21|    false|
# |    2|  13|19/11/2010|    48465.38|    false|
# |    2|  13|26/11/2010|    49693.62|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_130.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|   7|15/04/2011|    44535.96|    false|
# |   14|   7|22/04/2011|    68184.75|    false|
# |   14|   7|29/04/2011|     56749.7|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_131.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  14|08/04/2011|    21533.09|    false|
# |   14|  14|15/04/2011|    21091.25|    false|
# |   14|  14|22/04/2011|    24679.37|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_132.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  22|26/08/2011|    18727.43|    false|
# |   14|  22|02/09/2011|    16391.35|    false|
# |   14|  22|09/09/2011|    19089.12|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_133.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  29|19/08/2011|     8344.06|    false|
# |   14|  29|26/08/2011|     8774.74|    false|
# |   14|  29|02/09/2011|     8071.54|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_134.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  36|12/08/2011|       644.0|    false|
# |   14|  36|19/08/2011|       270.0|    false|
# |   14|  36|26/08/2011|       284.0|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_135.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  49|15/10/2010|    13654.51|    false|
# |   14|  49|22/10/2010|     8933.37|    false|
# |   14|  49|29/10/2010|     9569.39|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_136.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  58|11/11/2011|      8727.5|    false|
# |   14|  58|18/11/2011|      9315.0|    false|
# |   14|  58|25/11/2011|      9575.0|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_137.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  79|26/08/2011|    44176.39|    false|
# |   14|  79|02/09/2011|    28668.05|    false|
# |   14|  79|09/09/2011|    39150.64|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_138.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  90|19/08/2011|   107057.98|    false|
# |   14|  90|26/08/2011|    138231.7|    false|
# |   14|  90|02/09/2011|    90563.66|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_139.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   14|  98|13/05/2011|    17279.78|    false|
# |   14|  98|20/05/2011|    17233.66|    false|
# |   14|  98|27/05/2011|    16513.48|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_14.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    2|  21|03/06/2011|     8609.49|    false|
# |    2|  21|10/06/2011|     9474.59|    false|
# |    2|  21|17/06/2011|     9212.06|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_140.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   15|   7|09/07/2010|     26896.5|    false|
# |   15|   7|16/07/2010|     19851.9|    false|
# |   15|   7|23/07/2010|    18515.96|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_141.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   15|  14|02/07/2010|     14012.8|    false|
# |   15|  14|09/07/2010|    10372.82|    false|
# |   15|  14|16/07/2010|    12045.95|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_142.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   15|  22|11/02/2011|    11089.97|     true|
# |   15|  22|18/02/2011|     11967.4|    false|
# |   15|  22|25/02/2011|     9948.09|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_143.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   15|  29|04/02/2011|      4443.7|    false|
# |   15|  29|11/02/2011|     5183.79|     true|
# |   15|  29|18/02/2011|     7317.89|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_144.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   15|  36|28/01/2011|      1316.0|    false|
# |   15|  36|04/02/2011|      1505.0|    false|
# |   15|  36|11/02/2011|       678.0|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_145.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   15|  49|12/03/2010|    10459.81|    false|
# |   15|  49|19/03/2010|     14390.2|    false|
# |   15|  49|26/03/2010|    11746.11|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_146.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   15|  59|01/10/2010|      331.27|    false|
# |   15|  59|08/10/2010|      323.44|    false|
# |   15|  59|15/10/2010|      234.49|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_147.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   15|  80|29/04/2011|        21.4|    false|
# |   15|  80|06/05/2011|       22.91|    false|
# |   15|  80|13/05/2011|        17.2|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_148.csv ==
# ...
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_72.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    8|  17|18/11/2011|     7664.32|    false|
# |    8|  17|25/11/2011|    10299.07|     true|
# |    8|  17|02/12/2011|     8683.46|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_73.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    8|  24|18/05/2012|     2907.59|    false|
# |    8|  24|25/05/2012|     4347.48|    false|
# |    8|  24|01/06/2012|     3519.45|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_74.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    8|  31|11/05/2012|       814.9|    false|
# |    8|  31|18/05/2012|     1253.35|    false|
# |    8|  31|25/05/2012|      756.81|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_75.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    8|  38|04/05/2012|    70695.35|    false|
# |    8|  38|11/05/2012|    61643.13|    false|
# |    8|  38|18/05/2012|    60230.74|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_76.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    8|  52|16/09/2011|     1992.91|    false|
# |    8|  52|23/09/2011|     1489.47|    false|
# |    8|  52|30/09/2011|     2203.35|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_77.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    8|  67|23/03/2012|     3976.72|    false|
# |    8|  67|30/03/2012|     4233.46|    false|
# |    8|  67|06/04/2012|     5676.79|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_78.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    8|  82|16/12/2011|    29024.47|    false|
# |    8|  82|23/12/2011|     49338.4|    false|
# |    8|  82|30/12/2011|    22746.26|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_79.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    8|  93|09/12/2011|    32132.66|    false|
# |    8|  93|16/12/2011|    31654.61|    false|
# |    8|  93|23/12/2011|    35512.55|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_8.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    1|  58|27/05/2011|      2170.0|    false|
# |    1|  58|03/06/2011|      1455.0|    false|
# |    1|  58|10/06/2011|      2400.0|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_80.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|   3|11/03/2011|      4690.7|    false|
# |    9|   3|18/03/2011|     4398.29|    false|
# |    9|   3|25/03/2011|     5031.67|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_81.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|  10|04/03/2011|    11127.86|    false|
# |    9|  10|11/03/2011|    11760.07|    false|
# |    9|  10|18/03/2011|    13551.02|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_82.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|  18|19/08/2011|       29.91|    false|
# |    9|  18|26/08/2011|       19.94|    false|
# |    9|  18|02/09/2011|       53.73|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_83.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|  25|07/10/2011|     5123.79|    false|
# |    9|  25|14/10/2011|     6304.95|    false|
# |    9|  25|21/10/2011|     4718.42|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_84.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|  32|30/09/2011|      3443.9|    false|
# |    9|  32|07/10/2011|     3176.59|    false|
# |    9|  32|14/10/2011|     2853.04|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_85.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|  41|30/09/2011|      1516.0|    false|
# |    9|  41|07/10/2011|      1328.0|    false|
# |    9|  41|14/10/2011|      1798.0|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_86.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|  55|23/12/2011|    25440.98|    false|
# |    9|  55|30/12/2011|     17351.1|     true|
# |    9|  55|06/01/2012|     9349.75|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_87.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|  79|25/06/2010|    11585.77|    false|
# |    9|  79|02/07/2010|    13346.73|    false|
# |    9|  79|09/07/2010|    12255.11|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_88.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    9|  92|05/03/2010|    11176.21|    false|
# |    9|  92|12/03/2010|     10392.8|    false|
# |    9|  92|19/03/2010|     9636.54|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_89.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|   4|31/12/2010|    45097.48|     true|
# |   10|   4|07/01/2011|    55495.92|    false|
# |   10|   4|14/01/2011|     53326.9|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_9.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |    1|  79|01/04/2011|    35814.98|    false|
# |    1|  79|08/04/2011|     38752.0|    false|
# |    1|  79|15/04/2011|    31150.62|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_90.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  11|24/12/2010|    41524.43|    false|
# |   10|  11|31/12/2010|    35822.71|     true|
# |   10|  11|07/01/2011|    41213.41|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_91.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  19|09/09/2011|     3610.14|     true|
# |   10|  19|16/09/2011|     2849.65|    false|
# |   10|  19|23/09/2011|     2894.51|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_92.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  26|02/09/2011|     13259.4|    false|
# |   10|  26|09/09/2011|    14196.03|     true|
# |   10|  26|16/09/2011|    14130.25|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_93.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  33|26/08/2011|     10839.8|    false|
# |   10|  33|02/09/2011|     9680.51|    false|
# |   10|  33|09/09/2011|     8814.21|     true|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_94.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  41|19/08/2011|     15750.0|    false|
# |   10|  41|26/08/2011|    13295.05|    false|
# |   10|  41|02/09/2011|     16781.0|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_95.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  50|24/02/2012|      4445.0|    false|
# |   10|  50|02/03/2012|      5020.0|    false|
# |   10|  50|09/03/2012|      4220.0|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_96.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  60|23/12/2011|      1056.0|    false|
# |   10|  60|30/12/2011|       387.2|     true|
# |   10|  60|06/01/2012|       748.0|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_97.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  81|14/10/2011|    10495.77|    false|
# |   10|  81|21/10/2011|    10512.31|    false|
# |   10|  81|28/10/2011|    10068.44|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_98.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   10|  92|07/10/2011|    55517.16|    false|
# |   10|  92|14/10/2011|    53315.69|    false|
# |   10|  92|21/10/2011|    49770.57|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == sales_dataset/Sales_data_set_99.csv ==
#   columns: ['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday']
# +-----+----+----------+------------+---------+
# |Store|Dept|      Date|Weekly_Sales|IsHoliday|
# +-----+----+----------+------------+---------+
# |   11|   2|11/06/2010|    55820.63|    false|
# |   11|   2|18/06/2010|    57778.16|    false|
# |   11|   2|25/06/2010|    52843.39|    false|
# +-----+----+----------+------------+---------+
# only showing top 3 rows
#
# == store_dataset/stores_data_set (1).csv ==
#   columns: ['Store', 'Type', 'Size']
# +-----+----+------+
# |Store|Type|  Size|
# +-----+----+------+
# |    1|   A|151315|
# |    2|   A|202307|
# |    3|   B| 37392|
# +-----+----+------+
# only showing top 3 rows
#
#
# Identified DataFrames:
#  sales_df: Yes
#  stores_df: Yes
#  features_df: Yes
# Parsed date column: Date
# Normalized price column: Weekly_Sales
# Using store column: Store
#
# --- Business Calculations (best-effort) ---
#
# Monthly aggregation (month, total_sales):
# +-----+--------------------+
# |month|         total_sales|
# +-----+--------------------+
# | null|3.0122406110000007E7|
# +-----+--------------------+
#
# Weekly top-performing store (week, store, week_sales):
# +----+-----+--------------------+
# |week|Store|          week_sales|
# +----+-----+--------------------+
# |null|   11|3.0122406110000007E7|
# +----+-----+--------------------+
#
# Stores ordered by leap-year sales (lowest first):
# +-----+----------+
# |Store|leap_sales|
# +-----+----------+
# +-----+----------+
#
# Skipping department performance (no category or price found).
# Skipping April visits (missing visits, store_type or date).
# Skipping fuel price analysis (no fuel or store column).
#
# Writing analysis outputs and uploading to s3://retailstream-processed/
# Bucket exists: retailstream-processed
# Uploaded to s3://retailstream-processed/analysis_outputs/monthly_sales.csv
# Uploaded to s3://retailstream-processed/analysis_outputs/weekly_top_store.csv
# Uploaded to s3://retailstream-processed/analysis_outputs/leap_worst.csv
# Uploaded outputs: ['analysis_outputs/monthly_sales.csv', 'analysis_outputs/weekly_top_store.csv', 'analysis_outputs/leap_worst.csv']
#
# --- Pipeline finished ---
# RAW bucket: retailstream-raw
# PROCESSED bucket: retailstream-processed
# Uploaded 854 data files and 3 output objects.
# Local data dir for Spark: /content/data_for_spark
# Processed outputs dir: /content/processed_outputs
#
# You can now inspect results in S3 or download processed CSVs from s3://retailstream-processed/analysis_outputs/
#
# Download the results ZIP: /content/processed_outputs_zip.zip
